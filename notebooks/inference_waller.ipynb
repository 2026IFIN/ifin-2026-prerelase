# %% [markdown]
# # IFIN Inference (WallerDataset)
#
# Minimal inference walkthrough for WallerDataset-compatible data.

# %%
from pathlib import Path
import sys

def find_project_root(start: Path) -> Path:
    cur = start.resolve()
    for candidate in [cur, *cur.parents]:
        if (candidate / 'src').exists() and (candidate / 'configs').exists():
            return candidate
    raise RuntimeError('Project root not found.')

PROJECT_ROOT = find_project_root(Path.cwd())
SRC_ROOT = PROJECT_ROOT / 'src'
if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

PROJECT_ROOT

# %%
import torch

from config import load_config
from runner import infer

config = load_config(str(PROJECT_ROOT / 'configs' / 'default.yaml'))

# Update paths for your environment if needed
# config['data']['waller_path'] = '/path/to/wallerlab/dataset'
# config['data']['psf_path'] = '/path/to/wallerlab/dataset/psf.tiff'

config['data']['dataset'] = 'waller'
config['device'] = 'cuda' if torch.cuda.is_available() else 'cpu'
config['eval']['num_workers'] = 0
config['train']['num_workers'] = 0

config['device']

# %%
# Optional: set a checkpoint path generated by training
# ckpt = str(PROJECT_ROOT / 'outputs' / 'checkpoints' / 'ifin_last.pth')
ckpt = None

result = infer(config, checkpoint_path=ckpt)
result
